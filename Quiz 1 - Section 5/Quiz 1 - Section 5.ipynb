# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 1 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your own code

print("Ben Zamler")
# Out:
# Ben Zamler

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your own code


print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pytplot", and "pandas"

# %%
# Write your own code

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:darkblue"> Part I: Visualizing random variables </span>

# %% [markdown]
# <font size = "5">
#
# (a) Create two random variables ...
#
#
# - Call them "vec_x" and "vec_z"
# - Generate "vec_x" from a uniform distribution with (low = 10, high = 20, size = 1000)
# - Generate "vec_z" from a uniform distribution with (low = -2, high = 5, size = 1000)
# - Plot a histogram of each variable
#     - Label the axes and title
#     - Each graph should have a different title
#
# To get full points, plot the histograms on a grid (See Lecture 6)

# %%
# Write your own code

vec_x = np.random.uniform(low=10,high=20,size=1000)
vec_z = np.random.uniform(low=-2,high=5,size=1000)

fig,list_subfig = plt.subplots(1,2,figsize=(8,3))
plt.tight_layout()

list_subfig[0].hist(x = vec_x)
list_subfig[0].set_title("vec_x")
list_subfig[0].set_xlabel("Value")
list_subfig[0].set_ylabel("Frequency")


list_subfig[1].hist(x = vec_z)
list_subfig[1].set_title("vec_z")
list_subfig[1].set_xlabel("Value")
list_subfig[1].set_ylabel("Frequency")
# Out:
# Text(400.9040404040403, 0.5, 'Frequency')

# %% [markdown]
# <font size = "5">
#
# (b) Create a new variable "vec_y" by the formula
#
# $ y = e^x + 2x + 5$
#
# - Use element-by-element vector operations (no loops)
# - Produce a scatter plot of "vec_y" against "vec_x"
# - Label the axes and the title
# - Change the color to "red", "green" or "purple" (you choose)
#
# Hint: You can use the numpy "exp()" function with vector arrays

# %%
# Write your own code

vec_y =np.e**vec_x+2*vec_x+5

plt.scatter(x = vec_x, y = vec_y,color="red")
plt.title("y=e**2+2*x+5")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# ## <span style="color:darkblue"> Part II: Operations over multiple datasets </span>

# %% [markdown]
# <font size = "5">
#
# (c) Create two lists with ...
#
# - The names of the datasets
# - The years of the datasets (type manually based on the dataset names)
#
# To answer this question, you need to browse the Quiz folder
#
# You will find three datasets on the distribution of ages worldwide

# %%
# Write your own code

wdi_data1 = pd.read_csv("data_quiz/wdi_agedist_1980.csv")
wdi_data2 = pd.read_csv("data_quiz/wdi_agedist_2000.csv")
wdi_data3 = pd.read_csv("data_quiz/wdi_agedist_2020.csv")

list_wdi = [wdi_data1,wdi_data2,wdi_data3]
list_years = [1980,2020,2000]

print(list_wdi)
# Out:
# [       year yearcode     countryname countrycode  percent_ages0to14  \
# 0    1980.0   YR1980     Afghanistan         AFG          45.972855
# 1    1980.0   YR1980         Albania         ALB          36.306595
# 2    1980.0   YR1980         Algeria         DZA          46.408476
# 3    1980.0   YR1980  American Samoa         ASM          41.576075
# 4    1980.0   YR1980         Andorra         AND          23.732835
# ..      ...      ...             ...         ...                ...
# 265  1980.0   YR1980           World         WLD          35.387187
# 266     NaN      NaN             NaN         NaN                NaN
# 267     NaN      NaN             NaN         NaN                NaN
# 268     NaN      NaN             NaN         NaN                NaN
# 269     NaN      NaN             NaN         NaN                NaN
#
#      percent_ages15to64
# 0             51.502597
# 1             58.839669
# 2             50.452415
# 3             55.603533
# 4             69.585241
# ..                  ...
# 265           58.744703
# 266                 NaN
# 267                 NaN
# 268                 NaN
# 269                 NaN
#
# [270 rows x 6 columns],        year yearcode     countryname countrycode  percent_ages0to14  \
# 0    2000.0   YR2000     Afghanistan         AFG          49.718258
# 1    2000.0   YR2000         Albania         ALB          29.543870
# 2    2000.0   YR2000         Algeria         DZA          33.837187
# 3    2000.0   YR2000  American Samoa         ASM          40.154046
# 4    2000.0   YR2000         Andorra         AND          15.277431
# ..      ...      ...             ...         ...                ...
# 265  2000.0   YR2000           World         WLD          30.220558
# 266     NaN      NaN             NaN         NaN                NaN
# 267     NaN      NaN             NaN         NaN                NaN
# 268     NaN      NaN             NaN         NaN                NaN
# 269     NaN      NaN             NaN         NaN                NaN
#
#      percent_ages15to64
# 0             47.996934
# 1             62.634166
# 2             61.919167
# 3             56.666295
# 4             72.004993
# ..                  ...
# 265           62.893356
# 266                 NaN
# 267                 NaN
# 268                 NaN
# 269                 NaN
#
# [270 rows x 6 columns],        year yearcode     countryname countrycode  percent_ages0to14  \
# 0    2020.0   YR2020     Afghanistan         AFG          43.807912
# 1    2020.0   YR2020         Albania         ALB          16.471519
# 2    2020.0   YR2020         Algeria         DZA          30.647083
# 3    2020.0   YR2020  American Samoa         ASM          28.198272
# 4    2020.0   YR2020         Andorra         AND          13.334620
# ..      ...      ...             ...         ...                ...
# 265  2020.0   YR2020           World         WLD          25.699053
# 266     NaN      NaN             NaN         NaN                NaN
# 267     NaN      NaN             NaN         NaN                NaN
# 268     NaN      NaN             NaN         NaN                NaN
# 269     NaN      NaN             NaN         NaN                NaN
#
#      percent_ages15to64
# 0             53.775135
# 1             67.706368
# 2             63.335447
# 3             65.347810
# 4             72.470399
# ..                  ...
# 265           64.875804
# 266                 NaN
# 267                 NaN
# 268                 NaN
# 269                 NaN
#
# [270 rows x 6 columns]]

# %% [markdown]
# <font size = "5">
#
# (d) Create a loop that ...
#
#
# - Goes over the list of years
# - If the year $\ge$ 2008, print the message
#
# $\qquad$ "This dataset contains information on or after 2008.
#
# - If the year $<$ 2008, print the message
#
# $\qquad$ "This dataset contains information before 2008"

# %%
# Write your own code


list_years = [2020,2000]

for year in list_years: 
    if year >=2008: 
        print("This dataset contains information on or after 2008")
    else:
        print("This dataset contains information before 2008")
# Out:
# This dataset contains information on or after 2008
# This dataset contains information before 2008

# %% [markdown]
# <font size = "5">
#
# (e) Your goal is to convert all the ".csv" data files to ".xlsx" (Excel) files
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Create a new list called "list_newnames", with each element ending in ".xlsx" (including the subfolder "data_excel/")
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the ".csv" dataset and store it in an object called "dataset"
#     - Create a variable called "filename" from the "list_newnames", extracting the element "index"
#     - Store "dataset" as an excel file with name "filename".
#
#     $\qquad$ index = index + 1
#
# Note: Check that you did it correctly by trying to open your new excel files outside "VSCode"

# %%
# Write your own code

csv_list = ["data_quiz/wdi_agedist_1980.csv", "data_quiz/wdi_agedist_2000.csv", "data_quiz/wdi_agedist_2020.csv"]

index=0
for file in csv_list:
    dataset = pd.read_csv(csv_list[index])
    filename = csv_list[index].to_excel("data_quiz" + str([index + 1]) +".xlsx")
    index=index+1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 8
#       6 for file in csv_list:
#       7     dataset = pd.read_csv(csv_list[index])
# ----> 8     filename = csv_list[index].to_excel("data_quiz" + str([index + 1]) +".xlsx")
#       9     index=index+1
#
# AttributeError: 'str' object has no attribute 'to_excel'

# %% [markdown]
# <font size = "5">
#
# (f) Your goal is to open each dataset, create a new variable, then plot
#
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the dataset and store it in an object called "dataset"
#     - Create two new variables as
#
#     $\qquad$ percent_ages0to14 = dataset["percent_ages0to14"] <br>
#
#     - Calculate the proportion of the population 15 or older by computing "100 -  percent_ages0to14".
#     - Plot a histogram and label the axes
#     - Use plt.show() to display the plot
#     - Write
#
#     $\qquad$ index = index + 1
#
#
# This should produce a histogram for each dataset

# %%
# Write your own code

csv_list = ["data_quiz/wdi_agedist_1980.csv", "data_quiz/wdi_agedist_2000.csv", "data_quiz/wdi_agedist_2020.csv"]

index=0
for something in csv_list:
    dataset = pd.read.csv
    percent_ages0to14 = dataset["percent_ages0to14"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 7
#       5 index=0
#       6 for something in csv_list:
# ----> 7     dataset = pd.read.csv
#       8     percent_ages0to14 = dataset["percent_ages0to14"]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read'
